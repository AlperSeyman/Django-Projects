# %% [markdown]
# * After a user logs in, the server will return a JWT token
#
# ![image.png](attachment:image.png)
#
#
#
# * After decoding the token (JWT), get some data
# * This class describes what kind of data you expect inside the token.
# * Expecting the username.
#
# ![image-2.png](attachment:image-2.png)
#
# * This is the public version of a user (safe to return in an API).
#
# ![image-3.png](attachment:image-3.png)
#
#
# * This is the internal version of the user.
# * It includes everything in "User" plus the "hashed_password"
#
# ![image-4.png](attachment:image-4.png)
